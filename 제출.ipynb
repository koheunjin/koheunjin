# %%
# !git config --global user.email 'koheunjin'
# !git config --global user.name 'f2arnone@naver.com'

# %%
# !git add --all

# %%
# !git commit -m '원하는 아무 메세지2'
# !git push
# Out:
# [main 2e67e2c] 원하는 아무 메세지2
#  2 files changed, 1 insertion(+)
#  create mode 100644 Untitled0.ipynb
#  delete mode 100644 untitled.ipynb
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 742 bytes | 92.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/koheunjin/koheunjin.git
#    e565f74..2e67e2c  main -> main
